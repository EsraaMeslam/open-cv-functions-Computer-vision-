# %%
import cv2
import os
import matplotlib.pyplot as plt

# %%
# img_1=cv2.imread('cat.webp')
# img_2=cv2.imread('chameleon.webp')

# print(img_1.shape)
# print(img_2.shape)
# print((img_1.dtype))
# print((img_2.dtype))

# %%
img=cv2.imread('messi.webp',1)
plt.imshow(img,cmap='gray')
plt.title('Original image')
plt.show()

# %%
img=cv2.imread('messi.webp',1)
# b,g,r=cv2.split(img)

# img=cv2.merge((b,g,r))
print(img.shape)
ball=img[1350:1550,580:800]
img[1350:1550,100:320]=ball

plt.imshow(img,cmap='gray')
plt.title('image with after adding the spilted part')
plt.show()
# Out:
# (1600, 1285, 3)

# %%
plt.imshow(ball) #spillted part
plt.title('spilted part')
plt.show()

# %% [markdown]
# ### Wish U luck
